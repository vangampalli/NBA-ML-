# %%
import pandas as pd
import numpy as np

# %%
import os
current_directory = os.getcwd()
print(current_directory)
# Out:
# C:\Users\14389\c278_Python\worksheets\NBA-ML-

# %%
df=pd.read_csv('players.csv')

# %%
df
# Out:
#        Unnamed: 0          GAMEID TEAM             PLAYER     MP  FG  FGA  \
# 0               0  20161025CLENYK  CLE       LeBron James  32:23   9   14
# 1               1  20161025CLENYK  CLE       Kyrie Irving  29:48  12   22
# 2               2  20161025CLENYK  CLE         J.R. Smith  25:14   3   13
# 3               3  20161025CLENYK  CLE         Kevin Love  24:58   6   15
# 4               4  20161025CLENYK  CLE   Tristan Thompson  22:25   0    1
# ...           ...             ...  ...                ...    ...  ..  ...
# 59031           3  20190410PORSAC  SAC    Harrison Barnes  15:42   2    4
# 59032           4  20190410PORSAC  SAC    Nemanja Bjelica  11:55   3    4
# 59033           5  20190410PORSAC  SAC  Marvin Bagley III  30:15   8   15
# 59034           6  20190410PORSAC  SAC       Yogi Ferrell  28:39   7   13
# 59035           7  20190410PORSAC  SAC  Bogdan Bogdanović  27:16   5   16
#
#          FG%  3P  3PA  ...  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  +/-
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# GAMEID            0
# TEAM              0
# PLAYER            0
# MP                0
# FG                0
# FGA               0
# FG%             206
# 3P                0
# 3PA               0
# 3P%           11177
# FT                0
# FTA               0
# FT%           20197
# ORB               0
# DRB               0
# TRB               0
# AST               0
# STL               0
# BLK               0
# TOV               0
# PF                0
# PTS               0
# +/-               0
# dtype: int64
